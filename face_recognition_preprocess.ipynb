# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import Sequential
import pickle

# %%
main_path='/content/drive/MyDrive/images'

# %%
foldernames = os.listdir(main_path)

# %%
print(foldernames)
# Out:
# ['SHAHRIAR', 'ABIR', 'JALAL']

# %%
for folder in foldernames:
    individualpath = os.path.join(main_path, folder)
    imgnames = os.listdir(individualpath)
    label=foldernames.index(folder)
    print(folder,label)
# Out:
# SHAHRIAR 0
# ABIR 1
# JALAL 2

# %%
individualpath_for_abir=os.path.join(main_path,foldernames[1])
print(individualpath_for_abir)
# Out:
# /content/drive/MyDrive/images/ABIR

# %%
imgname_abir=os.listdir(individualpath_for_abir)

each_img_path_abir=os.path.join(individualpath_for_abir,imgname_abir[1])
print(each_img_path_abir)
# Out:
# /content/drive/MyDrive/images/ABIR/abir00002.png

# %%
read_img=cv2.imread(each_img_path_abir)
print(read_img.shape)
# Out:
# (400, 500, 3)

# %%
rgb_img=cv2.cvtColor(read_img,cv2.COLOR_BGR2RGB)
plt.figure()
plt.imshow(rgb_img)
plt.show()

# %%
X_train=[]
for folder in foldernames:
    individualpath = os.path.join(main_path, folder)
    imgnames = os.listdir(individualpath)
    label=foldernames.index(folder)
    for img in imgnames:
         try:
            each_img_path = os.path.join(individualpath, img)
            read_img = cv2.imread(each_img_path)
            rgb_img = cv2.cvtColor(read_img, cv2.COLOR_BGR2RGB)
            resize_img = cv2.resize(rgb_img, (256, 256))
            X_train.append([resize_img, label])
         except Exception as e:
                             print(f"Error processing image {each_img_path}: {e}")

# %%
with open('/content/drive/MyDrive/X2_train.pkl', 'wb') as file:
    pickle.dump(X_train, file)

# %%
np.random.shuffle(X_train)

# %%
X,Y=zip(*X_train)

# %%
X=np.array(X,dtype=np.float32)/255.0
Y=np.array(Y)

# %%
for i in range(10):
    plt.figure()
    plt.imshow(X[i])
    plt.xlabel(f"Label: {Y[i]}")
    plt.show()

# %%
plt.figure(figsize=(20,30))
for i in range(48):
  plt.subplot(8,6,i+1)
  plt.imshow(X[i])
  plt.xlabel(Y[i])
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
